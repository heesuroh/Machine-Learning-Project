# %% [markdown]
# # Introduction

# %% [markdown]
# # Library Imports

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 100)
from matplotlib import pyplot as plt
# %matplotlib inline

import seaborn as sns
sns.set_style('darkgrid')
import datetime

# %% [markdown]
# # Explorary Analysis

# %%
df_macro = pd.read_csv('GDP.csv')
df_macro.sort_values('DATE')
# Out:
#            DATE        GDP
# 0    1947-01-01    243.164
# 1    1947-04-01    245.968
# 2    1947-07-01    249.585
# 3    1947-10-01    259.745
# 4    1948-01-01    265.742
# ..          ...        ...
# 296  2021-01-01  22038.226
# 297  2021-04-01  22740.959
# 298  2021-07-01  23202.344
# 299  2021-10-01  24002.815
# 300  2022-01-01  24382.683
#
# [301 rows x 2 columns]

# %%
df_macro['year'] = pd.DatetimeIndex(df_macro['DATE']).year
df_macro['quarter'] = pd.DatetimeIndex(df_macro['DATE']).quarter
df_macro = df_macro.drop(['DATE'], axis = 1)
df_macro.sort_values('quarter')
# Out:
#            GDP  year  quarter
# 0      243.164  1947        1
# 172   5872.701  1990        1
# 168   5511.253  1989        1
# 164   5073.372  1988        1
# 160   4722.156  1987        1
# ..         ...   ...      ...
# 19     356.178  1951        4
# 223  11061.433  2002        4
# 39     460.463  1956        4
# 219  10660.465  2001        4
# 243  14715.058  2007        4
#
# [301 rows x 3 columns]

# %%
for i in [1, 2, 5, 10, 30]: #  Treasury bond yield
    df_yield = pd.read_csv('DGS{}.csv'.format(i))
    df_yield.columns = ['DATE', 'yield_{}y'.format(i)]
    df_yield['DATE'] = df_yield['DATE'].astype('datetime64[ns]')
    df_yield['year'] = pd.DatetimeIndex(df_yield['DATE']).year
    df_yield['quarter'] = pd.DatetimeIndex(df_yield['DATE']).quarter
    df_yield['yield_{}y'.format(i)] = pd.to_numeric(df_yield['yield_{}y'.format(i)], errors = 'coerce')
    df_yield = df_yield.sort_values('DATE').groupby(['year', 'quarter']).tail(1)
    df_yield = df_yield.drop(['DATE'], axis = 1)
    df_macro = pd.merge(df_macro, df_yield, on = ['year', 'quarter'])

# %%
df_macro.head().sort_values(['year', 'quarter'])
# Out:
#         GDP  year  quarter  yield_1y  yield_2y  yield_5y  yield_10y  yield_30y
# 0  1988.648  1977        1      5.40      6.01      6.94       7.42       7.79
# 1  2055.909  1977        2      5.72      6.08      6.70       7.20       7.58
# 2  2118.473  1977        3      6.66      6.82      7.11       7.41       7.68
# 3  2164.270  1977        4      6.98      7.22      7.54       7.78       8.03
# 4  2202.760  1978        1      7.48      7.70      7.97       8.15       8.33

# %%
df_macro.shape
# Out:
# (181, 8)

# %%
macro_data = {'inflation_exp': 'MICH', \
              'inflation_urban_all': 'CPIAUCSL', \
              'inflation_urban_ex_food_energy': 'CPILFESL', \
              'fed_effective_rate': 'DFF', \
              'unemployment_rate': 'UNRATE',\
              'crude_oil_price': 'WTISPLC',\
              'potential_gdp': 'NGDPPOT'}

# %%
for colname, filename in macro_data.items():
    df_temp = pd.read_csv('{}.csv'.format(filename))
    df_temp.columns = ['DATE', colname]
    df_temp['DATE'] = df_temp['DATE'].astype('datetime64[ns]')
    df_temp['year'] = pd.DatetimeIndex(df_temp['DATE']).year
    df_temp['quarter'] = pd.DatetimeIndex(df_temp['DATE']).quarter
    df_temp = df_temp.sort_values('DATE').groupby(['year', 'quarter']).tail(1)
    df_temp = df_temp.drop(['DATE'], axis = 1)
    df_macro = pd.merge(df_macro, df_temp, on = ['year', 'quarter'])

# %%
df_macro.shape
# Out:
# (177, 15)

# %%
df_macro.head()
# Out:
#         GDP  year  quarter  yield_1y  yield_2y  yield_5y  yield_10y  \
# 0  2202.760  1978        1      7.48      7.70      7.97       8.15
# 1  2331.633  1978        2      8.38      8.48      8.50       8.62
# 2  2395.053  1978        3      8.81      8.70      8.50       8.56
# 3  2476.949  1978        4     10.57      9.98      9.32       9.15
# 4  2526.610  1979        1     10.17      9.72      9.19       9.11
#
#    yield_30y  inflation_exp  inflation_urban_all  \
# 0       8.33            6.3                 63.4
# 1       8.62            6.5                 65.0
# 2       8.61            6.9                 66.5
# 3       8.96            7.3                 67.9
# 4       9.02            8.8                 69.9
#
#    inflation_urban_ex_food_energy  fed_effective_rate  unemployment_rate  \
# 0                            63.8                6.97                6.3
# 1                            65.2                8.01                5.9
# 2                            66.7                8.90                6.0
# 3                            68.0               10.84                6.0
# 4                            69.8               10.07                5.8
#
#    crude_oil_price  potential_gdp
# 0            14.85    2228.951872
# 1            14.85    2291.244375
# 2            14.85    2350.854505
# 3            14.85    2420.296133
# 4            15.85    2486.852276

# %%
for i in [1, 2, 5, 10, 30]: # inflation expectation by the Cleveland Fed
    dfname = 'inflation_exp_{}y'.format(i)
    dfname = pd.read_csv('EXPINF{}YR.csv'.format(i))
    dfname.columns = ['DATE', 'inflation_Exp_{}Y'.format(i)]
    dfname['DATE'] = dfname['DATE'].astype('datetime64[ns]')
    dfname['year'] = pd.DatetimeIndex(dfname['DATE']).year
    dfname['quarter'] = pd.DatetimeIndex(dfname['DATE']).quarter
    dfname = dfname.sort_values('DATE').groupby(['year', 'quarter']).tail(1)
    dfname = dfname.drop(['DATE'], axis = 1)
    df_macro = pd.merge(df_macro, dfname, on = ['year', 'quarter'])

# %%
df_macro.head()
# Out:
#         GDP  year  quarter  yield_1y  yield_2y  yield_5y  yield_10y  \
# 0  3274.302  1982        1     14.30     14.52     14.39      14.18
# 1  3331.972  1982        2     14.34     14.66     14.65      14.44
# 2  3366.322  1982        3     10.26     11.23     11.69      11.73
# 3  3402.561  1982        4      8.68      9.48     10.09      10.36
# 4  3473.413  1983        1      9.34      9.87     10.27      10.62
#
#    yield_30y  inflation_exp  inflation_urban_all  \
# 0      13.68            4.2                 94.7
# 1      13.91            4.6                 97.0
# 2      11.79            4.5                 97.7
# 3      10.43            3.7                 97.7
# 4      10.69            1.8                 98.1
#
#    inflation_urban_ex_food_energy  fed_effective_rate  unemployment_rate  \
# 0                            93.9               16.80                9.0
# 1                            96.1               14.58                9.6
# 2                            97.2               12.17               10.1
# 3                            97.2               11.20               10.8
# 4                            98.2               10.81               10.3
#
#    crude_oil_price  potential_gdp  inflation_Exp_1Y  inflation_Exp_2Y  \
# 0            28.48    3477.052316          6.387732          6.295533
# 1            35.07    3549.372701          5.445233          5.838871
# 2            35.63    3627.672682          6.339422          6.106970
# 3            31.72    3694.173716          4.571015          4.862399
# 4            28.82    3751.018696          4.062945          4.480367
#
#    inflation_Exp_5Y  inflation_Exp_10Y  inflation_Exp_30Y
# 0          6.027709           5.648130           4.655782
# 1          5.881698           5.602379           4.659658
# 2          6.002451           5.733214           4.756536
# 3          5.002224           4.862421           4.206251
# 4          4.701710           4.609992           4.050871

# %%
micro_data = {'pb_ratio': 'pb_ratio', \
              'long_term_growth': 'long_term_growth', \
              'debt_to_ev_ratio': 'debt_to_ev_ratio', \
             'market_cap': 'market_cap', 'pe_ratio': 'pe_ratio'}

# %%
df = pd.read_csv('stock_return_3m.csv')
df.head()
df = df[['stock', 'date', 'return_3m']]
df['date'] = df['date'].astype('datetime64[ns]')
df['year'] = pd.DatetimeIndex(df['date']).year
df['quarter'] = pd.DatetimeIndex(df['date']).quarter
df['return_3m'] = pd.to_numeric(df['return_3m'], errors = 'coerce')
df.loc[df['quarter'] == 1, 'year'] -= 1
df['quarter'] = df['quarter'] - 1
df.loc[df['quarter'] == 0, 'quarter'] = 4
df = df.sort_values('date').groupby(['stock', 'year', 'quarter']).tail(1)
df = df.drop(['date'], axis = 1)
df = df.sort_values(['stock', 'quarter'])

# %%
for filename, colname in micro_data.items():
    df_temp = pd.read_csv('{}.csv'.format(filename))
    df_temp = df_temp[['date', 'stock', colname]]
    df_temp[colname] = pd.to_numeric(df_temp[colname], errors = 'coerce')
    df_temp['date'] = df_temp['date'].astype('datetime64[ns]')
    df_temp['year'] = pd.DatetimeIndex(df_temp['date']).year
    df_temp['quarter'] = pd.DatetimeIndex(df_temp['date']).quarter
    df_temp = df_temp.sort_values('date').groupby(['quarter', 'year', 'stock']).tail(1)
    df_temp = df_temp.drop(['date'], axis = 1)
    df = pd.merge(df, df_temp, on = ['quarter', 'year', 'stock'])

# %%
df = pd.merge(df, df_macro, on = ['quarter', 'year'])

# %%
df.shape
# Out:
# (60768, 27)

# %%
df = df.sort_values(['stock', 'year', 'quarter'])

# %%
df[60:70]
# Out:
#       stock  return_3m    year  quarter  pb_ratio  long_term_growth  \
# 10672     A  21.855273  2020.0      1.0  4.579662               7.7
# 22453     A  14.224284  2020.0      2.0  5.708465               8.7
# 34205     A  17.591469  2020.0      3.0  6.261887               9.4
# 48000     A   7.475651  2020.0      4.0  7.440579               9.3
# 11391     A  18.576240  2021.0      1.0  8.071961              10.8
# 34869     A   1.474819  2021.0      3.0  9.650544              13.6
# 48650     A -17.001196  2021.0      4.0  8.946799              14.0
# 8990     AA   4.270463  2018.0      1.0  1.840952               8.6
# 20886    AA -13.822526  2018.0      2.0  1.628362              11.3
# 32668    AA -34.207921  2018.0      3.0  1.499505               4.5
#
#        debt_to_ev_ratio    market_cap   pe_ratio        GDP  yield_1y  \
# 10672         10.515422  2.217723e+10  29.563401  21481.367      0.17
# 22453          8.744965  2.728666e+10  40.549160  19477.444      0.16
# 34205          7.239969  3.112077e+10  45.618063  21138.574      0.12
# 48000          6.328367  3.635860e+10  51.462125  21477.597      0.10
# 11391          6.261707  3.873924e+10  48.803894  22038.226      0.07
# 34869          5.818652  4.768790e+10  49.076142  23202.344      0.09
# 48650          5.527824  4.821443e+10  40.539751  24002.815      0.39
# 8990          13.131701  8.370684e+09  30.196181  20143.716       NaN
# 20886         13.089416  8.741050e+09  35.610112  20492.492      2.33
# 32668         18.446072  7.533511e+09  41.815020  20659.102      2.59
#
#        yield_2y  yield_5y  yield_10y  yield_30y  inflation_exp  \
# 10672      0.23      0.37       0.70       1.35            2.2
# 22453      0.16      0.29       0.66       1.41            3.0
# 34205      0.13      0.28       0.69       1.46            2.6
# 48000      0.13      0.36       0.93       1.65            2.5
# 11391      0.16      0.92       1.74       2.41            3.1
# 34869      0.28      0.98       1.52       2.08            4.6
# 48650      0.73      1.26       1.52       1.90            4.8
# 8990        NaN       NaN        NaN        NaN            2.8
# 20886      2.52      2.73       2.85       2.98            3.0
# 32668      2.81      2.94       3.05       3.19            2.7
#
#        inflation_urban_all  inflation_urban_ex_food_energy  \
# 10672              258.165                         266.916
# 22453              257.217                         266.088
# 34205              260.190                         269.152
# 48000              261.564                         269.984
# 11391              265.028                         271.347
# 34869              274.214                         280.017
# 48650              280.126                         284.770
# 8990               249.581                         256.128
# 20886              251.118                         257.449
# 32668              252.239                         258.505
#
#        fed_effective_rate  unemployment_rate  crude_oil_price  potential_gdp  \
# 10672                0.08                4.4            29.21       21832.64
# 22453                0.08               11.0            38.31       21818.96
# 34205                0.09                7.9            39.63       22112.54
# 48000                0.09                6.7            47.02       22315.43
# 11391                0.06                6.0            62.33       22644.98
# 34869                0.06                4.7            71.65       23233.13
# 48650                0.07                3.9            71.71       23461.34
# 8990                 1.67                4.0            62.73       20234.99
# 20886                1.91                4.0            67.87       20503.32
# 32668                2.18                3.7            70.23       20682.68
#
#        inflation_Exp_1Y  inflation_Exp_2Y  inflation_Exp_5Y  \
# 10672          0.987074          1.082918          1.121101
# 22453          0.512757          0.802709          1.012906
# 34205          1.582764          1.346501          1.236315
# 48000          1.649521          1.404304          1.302465
# 11391          1.513838          1.388169          1.365860
# 34869          2.684137          2.007175          1.632602
# 48650          2.620309          2.048894          1.740795
# 8990           1.688744          1.772996          1.860728
# 20886          1.590995          1.772140          1.924010
# 32668          2.410015          2.206002          2.103109
#
#        inflation_Exp_10Y  inflation_Exp_30Y
# 10672           1.269775           1.814519
# 22453           1.231867           1.813111
# 34205           1.350999           1.857768
# 48000           1.417170           1.900938
# 11391           1.497404           1.958286
# 34869           1.642786           2.014232
# 48650           1.758975           2.092002
# 8990            1.970242           2.257159
# 20886           2.045903           2.310123
# 32668           2.136153           2.340414

# %%
df.hist(figsize = (20, 20), xrot = -45)
plt.show()

# %%
df.describe()
# Out:
#           return_3m          year       quarter      pb_ratio  \
# count  60768.000000  60768.000000  60768.000000  6.076700e+04
# mean       3.571368   2011.238547      2.485338  4.928740e+01
# std       18.883694      5.877614      1.122002  1.129986e+04
# min      -97.976190   2001.000000      1.000000 -1.003685e+04
# 25%       -5.992586   2006.000000      1.000000  1.520062e+00
# 50%        3.361415   2011.000000      2.000000  2.481791e+00
# 75%       12.849222   2016.000000      3.000000  4.241028e+00
# max      519.047619   2021.000000      4.000000  2.785410e+06
#
#        long_term_growth  debt_to_ev_ratio    market_cap      pe_ratio  \
# count      60768.000000      60755.000000  6.076800e+04  59461.000000
# mean          13.504497         24.025858  1.992141e+10     43.097762
# std           12.629475         88.136956  6.320553e+10    447.601791
# min         -284.800000          0.000000  1.275183e+05      0.020666
# 25%            8.330000          6.889079  1.474006e+09     14.169679
# 50%           12.133540         18.688256  4.483774e+09     19.815420
# 75%           16.500000         35.080108  1.489699e+10     29.299151
# max          396.478000      20796.686330  2.901640e+12  65000.000000
#
#                 GDP      yield_1y      yield_2y      yield_5y     yield_10y  \
# count  60768.000000  58517.000000  58517.000000  58517.000000  58517.000000
# mean   16290.767674      1.508103      1.714208      2.365195      3.016907
# std     3415.429543      1.540791      1.466446      1.303823      1.203594
# min    10470.231000      0.070000      0.130000      0.280000      0.660000
# 25%    13870.188000      0.210000      0.560000      1.390000      2.060000
# 50%    15842.267000      1.030000      1.270000      1.930000      2.730000
# 75%    18968.041000      2.360000      2.630000      3.340000      3.990000
# max    24002.815000      5.210000      5.160000      5.100000      5.420000
#
#           yield_30y  inflation_exp  inflation_urban_all  \
# count  58517.000000   60768.000000         60768.000000
# mean       3.683895       3.001761           223.642872
# std        1.136131       0.624936            25.925145
# min        1.350000       1.700000           176.100000
# 25%        2.820000       2.700000           202.800000
# 50%        3.560000       3.000000           227.223000
# 75%        4.770000       3.200000           242.637000
# max        5.750000       5.100000           280.126000
#
#        inflation_urban_ex_food_energy  fed_effective_rate  unemployment_rate  \
# count                    60768.000000        60768.000000       60768.000000
# mean                       228.640461            1.411636           5.967634
# std                         25.699882            1.637741           1.829860
# min                        184.700000            0.040000           3.500000
# 25%                        207.200000            0.090000           4.600000
# 50%                        227.405000            0.820000           5.400000
# 75%                        249.920000            2.180000           7.200000
# max                        284.770000            5.340000          11.000000
#
#        crude_oil_price  potential_gdp  inflation_Exp_1Y  inflation_Exp_2Y  \
# count     60768.000000   60768.000000      60768.000000      60768.000000
# mean         63.827310   16573.903997          1.883698          1.850269
# std          24.826724    3482.981381          0.672985          0.507640
# min          19.330000   10494.099700         -0.480678          0.555476
# 25%          45.480000   13792.048520          1.503148          1.503438
# 50%          60.560000   16382.923110          1.933676          1.846777
# 75%          82.410000   19307.290000          2.341925          2.221316
# max         133.930000   23461.340000          3.227172          2.930084
#
#        inflation_Exp_5Y  inflation_Exp_10Y  inflation_Exp_30Y
# count      60768.000000       60768.000000       60768.000000
# mean           1.872270           1.972780           2.289875
# std            0.433792           0.387208           0.269088
# min            1.012906           1.231867           1.813111
# 25%            1.537020           1.648906           2.091541
# 50%            1.812388           1.894122           2.212204
# 75%            2.241176           2.327409           2.553916
# max            2.813237           2.845305           2.891442

# %%
len(df[df['pb_ratio'] <= 0])
# Out:
# 1584

# %%
correlations = df.corr()
plt.figure(figsize = (10, 10))
sns.heatmap(correlations*100, annot = True, fmt = '.0f', cmap = 'RdBu_r')
plt.show()

# %%
df.dtypes
# Out:
# stock                              object
# return_3m                         float64
# year                              float64
# quarter                           float64
# pb_ratio                          float64
# long_term_growth                  float64
# debt_to_ev_ratio                  float64
# market_cap                        float64
# pe_ratio                          float64
# GDP                               float64
# yield_1y                          float64
# yield_2y                          float64
# yield_5y                          float64
# yield_10y                         float64
# yield_30y                         float64
# inflation_exp                     float64
# inflation_urban_all               float64
# inflation_urban_ex_food_energy    float64
# fed_effective_rate                float64
# unemployment_rate                 float64
# crude_oil_price                   float64
# potential_gdp                     float64
# inflation_Exp_1Y                  float64
# inflation_Exp_2Y                  float64
# inflation_Exp_5Y                  float64
# inflation_Exp_10Y                 float64
# inflation_Exp_30Y                 float64
# dtype: object

# %%
df.to_csv('ready_to_clean_data.csv', index = None)

# %% [markdown]
# # Data Cleaning

# %%
df = pd.read_csv('ready_to_clean_data.csv')

# %%
df.shape
# Out:
# (60768, 27)

# %%
df = df.drop_duplicates()

# %%
df.isnull().sum()
# Out:
# stock                                0
# return_3m                            0
# year                                 0
# quarter                              0
# pb_ratio                             1
# long_term_growth                     0
# debt_to_ev_ratio                    13
# market_cap                           0
# pe_ratio                          1307
# GDP                                  0
# yield_1y                          2251
# yield_2y                          2251
# yield_5y                          2251
# yield_10y                         2251
# yield_30y                         2251
# inflation_exp                        0
# inflation_urban_all                  0
# inflation_urban_ex_food_energy       0
# fed_effective_rate                   0
# unemployment_rate                    0
# crude_oil_price                      0
# potential_gdp                        0
# inflation_Exp_1Y                     0
# inflation_Exp_2Y                     0
# inflation_Exp_5Y                     0
# inflation_Exp_10Y                    0
# inflation_Exp_30Y                    0
# dtype: int64

# %%
df['check'] = df['pe_ratio'] < 0
print(df[df.pe_ratio.isnull()])
# Out:
#         stock  return_3m    year  quarter  pb_ratio  long_term_growth  \
# 4           A -32.351259  2002.0      1.0  2.025252          17.80714
# 23          A  10.685549  2009.0      4.0  3.067575          15.00000
# 39          A   0.476966  2014.0      3.0  2.407008           9.22500
# 71         AA -14.267407  2019.0      2.0  0.842159          -8.10000
# 73      AAL.O  21.390223  2014.0      1.0 -7.060081          39.15000
# ...       ...        ...     ...      ...       ...               ...
# 60527  ZBRA.O -31.067087  2015.0      2.0  5.609876          25.00000
# 60581    ZG.O  -3.053236  2013.0      3.0  3.174873          56.00000
# 60584    ZG.O -22.484732  2021.0      4.0  2.746937          86.90000
# 60617  ZION.O  23.508562  2009.0      1.0  0.174391           7.20000
# 60738     ZWS   7.293595  2013.0      4.0  3.140720          23.35000
#
#        debt_to_ev_ratio    market_cap  pe_ratio        GDP  yield_1y  \
# 4              7.631253  1.621654e+10       NaN  10783.500       NaN
# 23            25.796851  1.083819e+10       NaN  14651.248      0.47
# 39            11.767482  1.900356e+10       NaN  17743.227      0.13
# 71            25.555012  4.343367e+09       NaN  21289.268      1.92
# 73            73.948560  1.725753e+10       NaN  17144.281      0.13
# ...                 ...           ...       ...        ...       ...
# 60527         36.736565  5.744069e+09       NaN  18193.707      0.28
# 60581          0.000000  3.256730e+09       NaN  16911.068      0.10
# 60584         25.659064  1.608094e+10       NaN  24002.815      0.39
# 60617         78.587776  1.133750e+09       NaN  14430.901      0.57
# 60738         44.919934  2.640864e+09       NaN  17133.114      0.13
#
#        yield_2y  yield_5y  yield_10y  yield_30y  inflation_exp  \
# 4           NaN       NaN        NaN        NaN            2.7
# 23         1.14      2.69       3.85       4.63            2.5
# 39         0.58      1.78       2.52       3.21            3.0
# 71         1.75      1.76       2.00       2.52            2.7
# 73         0.44      1.73       2.73       3.56            3.2
# ...         ...       ...        ...        ...            ...
# 60527      0.64      1.63       2.35       3.11            2.7
# 60581      0.33      1.39       2.64       3.69            3.3
# 60584      0.73      1.26       1.52       1.90            4.8
# 60617      0.81      1.67       2.71       3.56            2.0
# 60738      0.38      1.75       3.04       3.96            3.0
#
#        inflation_urban_all  inflation_urban_ex_food_energy  \
# 4                  178.500                         189.200
# 23                 217.347                         220.881
# 39                 237.477                         238.786
# 71                 255.361                         262.945
# 73                 236.028                         236.625
# ...                    ...                             ...
# 60527              237.657                         242.064
# 60581              233.544                         234.700
# 60584              280.126                         284.770
# 60617              212.495                         218.253
# 60738              234.719                         235.759
#
#        fed_effective_rate  unemployment_rate  crude_oil_price  potential_gdp  \
# 4                    1.74                5.7            24.42    10993.29756
# 23                   0.05                9.9            74.30    15357.74147
# 39                   0.07                5.9            93.21    18115.68858
# 71                   2.40                3.6            54.66    21274.68000
# 73                   0.06                6.7           100.80    17773.46943
# ...                   ...                ...              ...            ...
# 60527                0.08                5.3            59.82    18481.76535
# 60581                0.06                7.2           106.29    17438.54851
# 60584                0.07                3.9            71.71    23461.34000
# 60617                0.16                8.7            47.98    15160.71793
# 60738                0.07                6.7            97.63    17620.56835
#
#        inflation_Exp_1Y  inflation_Exp_2Y  inflation_Exp_5Y  \
# 4              2.013877          2.307672          2.577104
# 23             1.786604          1.712095          1.767798
# 39             2.115039          1.896282          1.831570
# 71             1.609140          1.569616          1.540383
# 73             1.219462          1.382828          1.568777
# ...                 ...               ...               ...
# 60527          1.775055          1.695114          1.711298
# 60581          2.202423          1.908731          1.796818
# 60584          2.620309          2.048894          1.740795
# 60617         -0.480678          0.555476          1.275969
# 60738          1.924031          1.734090          1.686049
#
#        inflation_Exp_10Y  inflation_Exp_30Y  check
# 4               2.704655           2.829693  False
# 23              1.906408           2.289286  False
# 39              1.913118           2.212204  False
# 71              1.637053           2.036470  False
# 73              1.745194           2.133445  False
# ...                  ...                ...    ...
# 60527           1.824036           2.164157  False
# 60581           1.868801           2.180495  False
# 60584           1.758975           2.092002  False
# 60617           1.632766           2.178218  False
# 60738           1.785139           2.134786  False
#
# [1307 rows x 28 columns]

# %%
df = df[~df['return_3m'].isnull()]

# %%
df = df[~df['yield_1y'].isnull()]

# %%
df.head()
# Out:
#   stock  return_3m    year  quarter  pb_ratio  long_term_growth  \
# 0     A   5.759844  2001.0      1.0  1.706806          18.90909
# 1     A -39.846154  2001.0      2.0  1.782178          18.50000
# 2     A  45.831202  2001.0      3.0  1.105727          17.80769
# 3     A  22.623641  2001.0      4.0  1.612495          18.30714
# 5     A  11.729254  2004.0      3.0  2.121704          12.00000
#
#    debt_to_ev_ratio    market_cap   pe_ratio        GDP  yield_1y  yield_2y  \
# 0          3.926683  1.403653e+10  12.624599  10470.231      4.09      4.18
# 1          5.216324  1.485486e+10  14.424502  10599.000      3.72      4.25
# 2          9.022256  9.005459e+09  18.079301  10598.020      2.49      2.86
# 3          6.100677  1.321995e+10  26.365262  10660.465      2.17      3.07
# 5         11.870945  1.047452e+10  24.813444  12305.307      2.21      2.63
#
#    yield_5y  yield_10y  yield_30y  inflation_exp  inflation_urban_all  \
# 0      4.62       4.93       5.46            2.8                176.1
# 1      4.97       5.42       5.75            3.0                177.7
# 2      3.93       4.60       5.42            2.8                178.1
# 3      4.38       5.07       5.48            1.8                177.4
# 5      3.38       4.14       4.97            2.8                189.8
#
#    inflation_urban_ex_food_energy  fed_effective_rate  unemployment_rate  \
# 0                           184.7                5.29                4.3
# 1                           186.0                3.95                4.5
# 2                           187.1                2.75                5.0
# 3                           188.4                1.52                5.7
# 5                           197.5                1.94                5.4
#
#    crude_oil_price  potential_gdp  inflation_Exp_1Y  inflation_Exp_2Y  \
# 0            27.24    10494.09970          2.142245          2.355145
# 1            27.60    10644.10864          2.751184          2.769259
# 2            25.88    10769.24684          3.115226          2.888723
# 3            19.33    10882.90509          2.731375          2.611279
# 5            45.95    12363.22801          2.676771          2.403978
#
#    inflation_Exp_5Y  inflation_Exp_10Y  inflation_Exp_30Y  check
# 0          2.443328           2.498687           2.661808  False
# 1          2.813237           2.845305           2.891442  False
# 2          2.763910           2.749027           2.809119  False
# 3          2.598191           2.639346           2.754605  False
# 5          2.309944           2.355866           2.563130  False

# %%
df = df[df['pe_ratio'].isnull() | (df['pe_ratio'] >= 0)]

# %%
df = df[df['pb_ratio'].isnull() | (df['pb_ratio'] >= 0)]

# %%
df = df[df['debt_to_ev_ratio'].isnull() | (df['debt_to_ev_ratio'] >= 0)]

# %%
df = df[df.long_term_growth >= -100 | df.long_term_growth.isnull()]

# %%
df.isnull().sum()
# Out:
# stock                                0
# return_3m                            0
# year                                 0
# quarter                              0
# pb_ratio                             1
# long_term_growth                     0
# debt_to_ev_ratio                     9
# market_cap                           0
# pe_ratio                          1042
# GDP                                  0
# yield_1y                             0
# yield_2y                             0
# yield_5y                             0
# yield_10y                            0
# yield_30y                            0
# inflation_exp                        0
# inflation_urban_all                  0
# inflation_urban_ex_food_energy       0
# fed_effective_rate                   0
# unemployment_rate                    0
# crude_oil_price                      0
# potential_gdp                        0
# inflation_Exp_1Y                     0
# inflation_Exp_2Y                     0
# inflation_Exp_5Y                     0
# inflation_Exp_10Y                    0
# inflation_Exp_30Y                    0
# check                                0
# dtype: int64

# %%
df['contains_na'] = df['debt_to_ev_ratio'].isnull() | df['pe_ratio'].isnull()

# %%
incomplete_stock_list = df.groupby('stock')['contains_na', 'stock'].sum()
# Out:
# C:\Users\rohhe\AppData\Local\Temp/ipykernel_23936/2445570019.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   incomplete_stock_list = df.groupby('stock')['contains_na', 'stock'].sum()

# %%
incomplete_stock_list['problematic'] = incomplete_stock_list['contains_na'] > 0

# %%
df = pd.merge(df, incomplete_stock_list, on = 'stock')

# %%
len(df)
# Out:
# 54838

# %%
df = df[df.problematic == False]

# %%
len(df)
# Out:
# 30633

# %%
df.isnull().sum()
# Out:
# stock                             0
# return_3m                         0
# year                              0
# quarter                           0
# pb_ratio                          0
# long_term_growth                  0
# debt_to_ev_ratio                  0
# market_cap                        0
# pe_ratio                          0
# GDP                               0
# yield_1y                          0
# yield_2y                          0
# yield_5y                          0
# yield_10y                         0
# yield_30y                         0
# inflation_exp                     0
# inflation_urban_all               0
# inflation_urban_ex_food_energy    0
# fed_effective_rate                0
# unemployment_rate                 0
# crude_oil_price                   0
# potential_gdp                     0
# inflation_Exp_1Y                  0
# inflation_Exp_2Y                  0
# inflation_Exp_5Y                  0
# inflation_Exp_10Y                 0
# inflation_Exp_30Y                 0
# check                             0
# contains_na_x                     0
# contains_na_y                     0
# problematic                       0
# dtype: int64

# %%
for col in df.columns:
    if col != 'stock':
        print('Variable : ', col)
        sns.violinplot(col, data = df)
        plt.show()
# Out:
# Variable :  return_3m
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  year
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  quarter
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  pb_ratio
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  long_term_growth
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  debt_to_ev_ratio
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  market_cap
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  pe_ratio
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  GDP
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  yield_1y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  yield_2y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  yield_5y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  yield_10y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  yield_30y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  inflation_exp
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  inflation_urban_all
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  inflation_urban_ex_food_energy
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  fed_effective_rate
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  unemployment_rate
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  crude_oil_price
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  potential_gdp
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  inflation_Exp_1Y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  inflation_Exp_2Y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  inflation_Exp_5Y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  inflation_Exp_10Y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  inflation_Exp_30Y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  check
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  contains_na_x
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  contains_na_y
# C:\Users\rohhe\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Variable :  problematic

# %%
df = df.drop(['check', 'contains_na_x', 'contains_na_y', 'problematic'], axis = 1)

# %%
df.head()
# Out:
#     stock  return_3m    year  quarter   pb_ratio  long_term_growth  \
# 63     AA -13.822526  2018.0      2.0   1.628362             11.30
# 64     AA -34.207921  2018.0      3.0   1.499505              4.50
# 65     AA   5.944319  2018.0      4.0   0.950347              4.00
# 66  AAL.O -25.395774  2015.0      1.0  18.215095             23.20
# 67  AAL.O  -2.536477  2015.0      2.0  10.024215             20.05
#
#     debt_to_ev_ratio    market_cap   pe_ratio        GDP  yield_1y  yield_2y  \
# 63         13.089416  8.741050e+09  35.610112  20492.492      2.33      2.52
# 64         18.446072  7.533511e+09  41.815020  20659.102      2.59      2.81
# 65         23.300936  4.957012e+09  80.638311  20813.325      2.63      2.48
# 66         37.980535  3.676918e+10  13.417155  17991.348      0.26      0.56
# 67         50.932689  2.766692e+10   8.717757  18193.707      0.28      0.64
#
#     yield_5y  yield_10y  yield_30y  inflation_exp  inflation_urban_all  \
# 63      2.73       2.85       2.98            3.0              251.118
# 64      2.94       3.05       3.19            2.7              252.239
# 65      2.51       2.69       3.02            2.7              252.551
# 66      1.37       1.94       2.54            3.0              235.976
# 67      1.63       2.35       3.11            2.7              237.657
#
#     inflation_urban_ex_food_energy  fed_effective_rate  unemployment_rate  \
# 63                         257.449                1.91                4.0
# 64                         258.505                2.18                3.7
# 65                         259.934                2.40                3.9
# 66                         240.755                0.06                5.4
# 67                         242.064                0.08                5.3
#
#     crude_oil_price  potential_gdp  inflation_Exp_1Y  inflation_Exp_2Y  \
# 63            67.87    20503.32000          1.590995          1.772140
# 64            70.23    20682.68000          2.410015          2.206002
# 65            49.52    20881.05000          1.981070          1.995989
# 66            47.82    18297.43359          0.798439          1.190572
# 67            59.82    18481.76535          1.775055          1.695114
#
#     inflation_Exp_5Y  inflation_Exp_10Y  inflation_Exp_30Y
# 63          1.924010           2.045903           2.310123
# 64          2.103109           2.136153           2.340414
# 65          2.019533           2.091349           2.323323
# 66          1.495196           1.703487           2.115891
# 67          1.711298           1.824036           2.164157

# %%
df.sort_values(by = "pb_ratio", ascending = False)
# Out:
#         stock   return_3m    year  quarter      pb_ratio  long_term_growth  \
# 48418  TRIP.O   41.491472  2011.0      4.0  2.785410e+06          17.50000
# 43770  SHLS.O  -29.876543  2021.0      4.0  4.741895e+03          34.67900
# 12147     CPB  -10.524073  2002.0      4.0  3.207567e+03           6.30000
# 53800      WU   -0.202265  2008.0      2.0  2.472000e+03          13.25000
# 9326      CCK  -10.530547  2014.0      2.0  2.298942e+03           9.80000
# ...       ...         ...     ...      ...           ...               ...
# 34107      NC    0.417226  2012.0      1.0  1.230693e-01          21.70000
# 25856  INVE.O  -32.631579  2001.0      1.0  1.162000e-01          40.00000
# 34102      NC   19.416383  2010.0      1.0  1.128396e-01          23.50000
# 16568     EHC  467.307692  2003.0      2.0  5.186828e-02          11.50000
# 16567     EHC  519.047619  2003.0      1.0  8.478469e-03          13.08571
#
#        debt_to_ev_ratio    market_cap    pe_ratio        GDP  yield_1y  \
# 48418          0.000000  3.365861e+09   21.560124  15842.267      0.12
# 43770          5.893713  4.054320e+09  540.600667  24002.815      0.39
# 12147         28.943889  9.632532e+09   17.666940  11061.433      1.32
# 53800         17.087861  1.829213e+10   21.732823  14865.701      2.36
# 9326          37.347026  6.896827e+09   22.717934  17462.703      0.11
# ...                 ...           ...         ...        ...       ...
# 34107         18.857727  7.905847e+08    0.895556  16068.824      0.19
# 25856          0.286347  2.318216e+08    3.185479  10470.231      4.09
# 34102         62.721915  4.990818e+08    5.266400  14764.611      0.41
# 16568        100.712425  2.061421e+08    0.731860  11312.766      1.09
# 16567        106.469627  3.369631e+07    0.119631  11174.129      1.19
#
#        yield_2y  yield_5y  yield_10y  yield_30y  inflation_exp  \
# 48418      0.25      0.83       1.89       2.89            3.1
# 43770      0.73      1.26       1.52       1.90            4.8
# 12147      1.61      2.78       3.83       5.03            2.5
# 53800      2.63      3.34       3.99       4.53            5.1
# 9326       0.47      1.62       2.53       3.34            3.1
# ...         ...       ...        ...        ...            ...
# 34107      0.33      1.04       2.23       3.35            3.9
# 25856      4.18      4.62       4.93       5.46            2.8
# 34102      1.02      2.55       3.84       4.72            2.7
# 16568      1.32      2.46       3.54       4.81            2.1
# 16567      1.51      2.78       3.83       5.07            3.1
#
#        inflation_urban_all  inflation_urban_ex_food_energy  \
# 48418              227.223                         227.405
# 43770              280.126                         284.770
# 12147              181.800                         192.100
# 53800              217.463                         215.424
# 9326               237.231                         237.837
# ...                    ...                             ...
# 34107              228.807                         228.478
# 25856              176.100                         184.700
# 34102              217.353                         220.783
# 16568              183.100                         193.000
# 16567              183.900                         192.500
#
#        fed_effective_rate  unemployment_rate  crude_oil_price  potential_gdp  \
# 48418                0.04                8.5            98.57    16382.92311
# 43770                0.07                3.9            71.71    23461.34000
# 12147                1.16                6.0            29.42    11360.39761
# 53800                2.47                5.6           133.93    14821.57825
# 9326                 0.09                6.1           105.79    17954.72347
# ...                   ...                ...              ...            ...
# 34107                0.09                8.2           106.19    16553.78162
# 25856                5.29                4.3            27.24    10494.09970
# 34102                0.09                9.9            81.24    15445.96164
# 16568                1.45                6.3            30.72    11586.90069
# 16567                1.38                5.9            33.55    11482.04284
#
#        inflation_Exp_1Y  inflation_Exp_2Y  inflation_Exp_5Y  \
# 48418          1.711663          1.550482          1.522191
# 43770          2.620309          2.048894          1.740795
# 12147          1.951158          2.045936          2.199139
# 53800          2.728512          2.436477          2.283534
# 9326           1.526546          1.572693          1.684508
# ...                 ...               ...               ...
# 34107          1.362054          1.357174          1.425537
# 25856          2.142245          2.355145          2.443328
# 34102          1.970139          1.846777          1.881111
# 16568          2.284731          2.019628          1.909655
# 16567          1.903343          1.897316          1.961785
#
#        inflation_Exp_10Y  inflation_Exp_30Y
# 48418           1.642213           2.048818
# 43770           1.758975           2.092002
# 12147           2.327409           2.572735
# 53800           2.303466           2.517528
# 9326            1.830090           2.178744
# ...                  ...                ...
# 34107           1.580148           2.019441
# 25856           2.498687           2.661808
# 34102           2.006760           2.353377
# 16568           1.978814           2.313671
# 16567           2.078386           2.398355
#
# [30633 rows x 27 columns]

# %%
df.to_csv('data_cleaned.csv', index = None)

# %% [markdown]
# ## Feature Engineering

# %%
df_cleaned = pd.read_csv('data_cleaned.csv')
df_cleaned['yield_spread'] = df_cleaned['yield_10y'] - df_cleaned['yield_2y']
df_cleaned['gdp_gap'] = (df_cleaned['GDP'] - df_cleaned['potential_gdp'])/df_cleaned['potential_gdp'].astype("float")

# %%
df_time_series = df_cleaned.groupby(['year', 'quarter']).mean()

# %%
df_time_series.head()
# Out:
#                 return_3m  pb_ratio  long_term_growth  debt_to_ev_ratio  \
# year   quarter
# 2001.0 1.0      12.997214  3.865882         15.527482         21.981270
#        2.0     -10.207513  3.839058         14.600254         24.221387
#        3.0      19.216038  4.186212         14.471431         24.919493
#        4.0       7.649642  4.013016         14.514070         23.387138
# 2002.0 2.0     -13.469169  4.148375         14.253744         21.629029
#
#                   market_cap   pe_ratio        GDP  yield_1y  yield_2y  \
# year   quarter
# 2001.0 1.0      1.480686e+10  23.311434  10470.231      4.09      4.18
#        2.0      1.287177e+10  22.648094  10599.000      3.72      4.25
#        3.0      1.328995e+10  19.538218  10598.020      2.49      2.86
#        4.0      1.496919e+10  50.889172  10660.465      2.17      3.07
# 2002.0 2.0      1.261762e+10  47.086569  10887.460      2.06      2.90
#
#                 yield_5y  yield_10y  yield_30y  inflation_exp  \
# year   quarter
# 2001.0 1.0          4.62       4.93       5.46            2.8
#        2.0          4.97       5.42       5.75            3.0
#        3.0          3.93       4.60       5.42            2.8
#        4.0          4.38       5.07       5.48            1.8
# 2002.0 2.0          4.09       4.86       5.70            2.7
#
#                 inflation_urban_all  inflation_urban_ex_food_energy  \
# year   quarter
# 2001.0 1.0                    176.1                           184.7
#        2.0                    177.7                           186.0
#        3.0                    178.1                           187.1
#        4.0                    177.4                           188.4
# 2002.0 2.0                    179.6                           190.2
#
#                 fed_effective_rate  unemployment_rate  crude_oil_price  \
# year   quarter
# 2001.0 1.0                    5.29                4.3            27.24
#        2.0                    3.95                4.5            27.60
#        3.0                    2.75                5.0            25.88
#        4.0                    1.52                5.7            19.33
# 2002.0 2.0                    1.73                5.8            25.52
#
#                 potential_gdp  inflation_Exp_1Y  inflation_Exp_2Y  \
# year   quarter
# 2001.0 1.0        10494.09970          2.142245          2.355145
#        2.0        10644.10864          2.751184          2.769259
#        3.0        10769.24684          3.115226          2.888723
#        4.0        10882.90509          2.731375          2.611279
# 2002.0 2.0        11104.69167          2.341925          2.470188
#
#                 inflation_Exp_5Y  inflation_Exp_10Y  inflation_Exp_30Y  \
# year   quarter
# 2001.0 1.0              2.443328           2.498687           2.661808
#        2.0              2.813237           2.845305           2.891442
#        3.0              2.763910           2.749027           2.809119
#        4.0              2.598191           2.639346           2.754605
# 2002.0 2.0              2.636385           2.730369           2.835529
#
#                 yield_spread   gdp_gap
# year   quarter
# 2001.0 1.0              0.75 -0.002274
#        2.0              1.17 -0.004238
#        3.0              1.74 -0.015900
#        4.0              2.00 -0.020439
# 2002.0 2.0              1.96 -0.019562

# %%
plt.scatter(df_time_series.fed_effective_rate, df_time_series.return_3m)
plt.xlabel('The Fed Effective Rate (%)')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
plt.scatter(df_time_series.yield_10y, df_time_series.return_3m)
plt.xlabel('The 10-year Teasury Yield (%)')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
plt.scatter(df_time_series['yield_spread'], df_time_series['return_3m'])
plt.xlabel('The Yield Spread (%)')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
plt.hist(df_time_series['return_3m'])
# Out:
# (array([ 2.,  1.,  2.,  6.,  5., 21., 26.,  8.,  6.,  4.]),
#  array([-25.90824431, -20.95336974, -15.99849516, -11.04362059,
#          -6.08874601,  -1.13387144,   3.82100314,   8.77587771,
#          13.73075229,  18.68562686,  23.64050144]),
#  <BarContainer object of 10 artists>)

# %%
df_2021_Q1 = df_cleaned[(df_cleaned.year == 2021) & (df_cleaned.quarter == 1)]
plt.scatter(df_2021_Q1['pe_ratio'], df_2021_Q1['return_3m'])
plt.xlabel('P/E Ratio')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
plt.scatter(df_2021_Q1['pb_ratio'], df_2021_Q1['return_3m'])
plt.xlabel('P/B Ratio')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
plt.scatter(df_2021_Q1['debt_to_ev_ratio'], df_2021_Q1['return_3m'])
plt.xlabel('Debt to EV Ratio')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
plt.scatter(np.log(df_2021_Q1['market_cap']), df_2021_Q1['return_3m'])
plt.xlabel('Log Market Capitalization')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
plt.scatter(df_2021_Q1['long_term_growth'], df_2021_Q1['return_3m'])
plt.xlabel('Long Term Growth (%)')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
plt.scatter(df_time_series['gdp_gap'], df_time_series['return_3m'])
plt.xlabel('GDP Gap (%)')
plt.ylabel('Mean Stock Return (%)')
plt.show()

# %%
correlations = df_time_series.corr()
plt.figure(figsize = (10, 10))
sns.heatmap(correlations*100, annot = True, fmt = '.0f', cmap = 'RdBu_r')
plt.show()

# %%
df_cleaned.head()
# Out:
#    stock  return_3m    year  quarter   pb_ratio  long_term_growth  \
# 0     AA -13.822526  2018.0      2.0   1.628362             11.30
# 1     AA -34.207921  2018.0      3.0   1.499505              4.50
# 2     AA   5.944319  2018.0      4.0   0.950347              4.00
# 3  AAL.O -25.395774  2015.0      1.0  18.215095             23.20
# 4  AAL.O  -2.536477  2015.0      2.0  10.024215             20.05
#
#    debt_to_ev_ratio    market_cap   pe_ratio        GDP  yield_1y  yield_2y  \
# 0         13.089416  8.741050e+09  35.610112  20492.492      2.33      2.52
# 1         18.446072  7.533511e+09  41.815020  20659.102      2.59      2.81
# 2         23.300936  4.957012e+09  80.638311  20813.325      2.63      2.48
# 3         37.980535  3.676918e+10  13.417155  17991.348      0.26      0.56
# 4         50.932689  2.766692e+10   8.717757  18193.707      0.28      0.64
#
#    yield_5y  yield_10y  yield_30y  inflation_exp  inflation_urban_all  \
# 0      2.73       2.85       2.98            3.0              251.118
# 1      2.94       3.05       3.19            2.7              252.239
# 2      2.51       2.69       3.02            2.7              252.551
# 3      1.37       1.94       2.54            3.0              235.976
# 4      1.63       2.35       3.11            2.7              237.657
#
#    inflation_urban_ex_food_energy  fed_effective_rate  unemployment_rate  \
# 0                         257.449                1.91                4.0
# 1                         258.505                2.18                3.7
# 2                         259.934                2.40                3.9
# 3                         240.755                0.06                5.4
# 4                         242.064                0.08                5.3
#
#    crude_oil_price  potential_gdp  inflation_Exp_1Y  inflation_Exp_2Y  \
# 0            67.87    20503.32000          1.590995          1.772140
# 1            70.23    20682.68000          2.410015          2.206002
# 2            49.52    20881.05000          1.981070          1.995989
# 3            47.82    18297.43359          0.798439          1.190572
# 4            59.82    18481.76535          1.775055          1.695114
#
#    inflation_Exp_5Y  inflation_Exp_10Y  inflation_Exp_30Y  yield_spread  \
# 0          1.924010           2.045903           2.310123          0.33
# 1          2.103109           2.136153           2.340414          0.24
# 2          2.019533           2.091349           2.323323          0.21
# 3          1.495196           1.703487           2.115891          1.38
# 4          1.711298           1.824036           2.164157          1.71
#
#     gdp_gap
# 0 -0.000528
# 1 -0.001140
# 2 -0.003243
# 3 -0.016728
# 4 -0.015586

# %%
df_cleaned['is_inversion'] = (df_cleaned['yield_spread'] < 0).astype(int)

# %%
df_cleaned['log_market_cap'] = np.log(df_cleaned['market_cap'])

# %%
micro_var = ['pe_ratio', 'pb_ratio', 'market_cap', 'debt_to_ev_ratio']
for var in micro_var:
    new_var_name1 = var + "_gdp_gap"
    df_cleaned[new_var_name1] = df_cleaned[var]*df_cleaned["gdp_gap"]
    new_var_name2 = var + "_yield_spread"
    df_cleaned[new_var_name2] = df_cleaned[var]*df_cleaned["yield_spread"]
    new_var_name3 = var + "_is_inversion"
    df_cleaned[new_var_name3] = df_cleaned[var]*df_cleaned["yield_spread"]

# %%
df_abt = df_cleaned.drop(['market_cap', 'GDP', 'potential_gdp'], axis = 1)

# %%
df_abt.head()
# Out:
#    stock  return_3m    year  quarter   pb_ratio  long_term_growth  \
# 0     AA -13.822526  2018.0      2.0   1.628362             11.30
# 1     AA -34.207921  2018.0      3.0   1.499505              4.50
# 2     AA   5.944319  2018.0      4.0   0.950347              4.00
# 3  AAL.O -25.395774  2015.0      1.0  18.215095             23.20
# 4  AAL.O  -2.536477  2015.0      2.0  10.024215             20.05
#
#    debt_to_ev_ratio   pe_ratio  yield_1y  yield_2y  yield_5y  yield_10y  \
# 0         13.089416  35.610112      2.33      2.52      2.73       2.85
# 1         18.446072  41.815020      2.59      2.81      2.94       3.05
# 2         23.300936  80.638311      2.63      2.48      2.51       2.69
# 3         37.980535  13.417155      0.26      0.56      1.37       1.94
# 4         50.932689   8.717757      0.28      0.64      1.63       2.35
#
#    yield_30y  inflation_exp  inflation_urban_all  \
# 0       2.98            3.0              251.118
# 1       3.19            2.7              252.239
# 2       3.02            2.7              252.551
# 3       2.54            3.0              235.976
# 4       3.11            2.7              237.657
#
#    inflation_urban_ex_food_energy  fed_effective_rate  unemployment_rate  \
# 0                         257.449                1.91                4.0
# 1                         258.505                2.18                3.7
# 2                         259.934                2.40                3.9
# 3                         240.755                0.06                5.4
# 4                         242.064                0.08                5.3
#
#    crude_oil_price  inflation_Exp_1Y  inflation_Exp_2Y  inflation_Exp_5Y  \
# 0            67.87          1.590995          1.772140          1.924010
# 1            70.23          2.410015          2.206002          2.103109
# 2            49.52          1.981070          1.995989          2.019533
# 3            47.82          0.798439          1.190572          1.495196
# 4            59.82          1.775055          1.695114          1.711298
#
#    inflation_Exp_10Y  inflation_Exp_30Y  yield_spread   gdp_gap  is_inversion  \
# 0           2.045903           2.310123          0.33 -0.000528             0
# 1           2.136153           2.340414          0.24 -0.001140             0
# 2           2.091349           2.323323          0.21 -0.003243             0
# 3           1.703487           2.115891          1.38 -0.016728             0
# 4           1.824036           2.164157          1.71 -0.015586             0
#
#    log_market_cap  pe_ratio_gdp_gap  pe_ratio_yield_spread  \
# 0       22.891296         -0.018806              11.751337
# 1       22.742627         -0.047669              10.035605
# 2       22.324069         -0.261540              16.934045
# 3       24.327926         -0.224447              18.515673
# 4       24.043503         -0.135876              14.907365
#
#    pe_ratio_is_inversion  pb_ratio_gdp_gap  pb_ratio_yield_spread  \
# 0              11.751337         -0.000860               0.537360
# 1              10.035605         -0.001709               0.359881
# 2              16.934045         -0.003082               0.199573
# 3              18.515673         -0.304708              25.136831
# 4              14.907365         -0.156238              17.141407
#
#    pb_ratio_is_inversion  market_cap_gdp_gap  market_cap_yield_spread  \
# 0               0.537360       -4.616232e+06             2.884546e+09
# 1               0.359881       -8.588109e+06             1.808043e+09
# 2               0.199573       -1.607743e+07             1.040972e+09
# 3              25.136831       -6.150871e+08             5.074147e+10
# 4              17.141407       -4.312190e+08             4.731044e+10
#
#    market_cap_is_inversion  debt_to_ev_ratio_gdp_gap  \
# 0             2.884546e+09                 -0.006913
# 1             1.808043e+09                 -0.021028
# 2             1.040972e+09                 -0.075574
# 3             5.074147e+10                 -0.635351
# 4             4.731044e+10                 -0.793841
#
#    debt_to_ev_ratio_yield_spread  debt_to_ev_ratio_is_inversion
# 0                       4.319507                       4.319507
# 1                       4.427057                       4.427057
# 2                       4.893196                       4.893196
# 3                      52.413138                      52.413138
# 4                      87.094898                      87.094898

# %%
print(df_abt.is_inversion.mean())
# Out:
# 0.05249241014592106

# %%
df_abt['yq'] = (df_abt['year']*10+df_abt['quarter']).astype(int)
df_abt.head()
# Out:
#    stock  return_3m    year  quarter   pb_ratio  long_term_growth  \
# 0     AA -13.822526  2018.0      2.0   1.628362             11.30
# 1     AA -34.207921  2018.0      3.0   1.499505              4.50
# 2     AA   5.944319  2018.0      4.0   0.950347              4.00
# 3  AAL.O -25.395774  2015.0      1.0  18.215095             23.20
# 4  AAL.O  -2.536477  2015.0      2.0  10.024215             20.05
#
#    debt_to_ev_ratio   pe_ratio  yield_1y  yield_2y  yield_5y  yield_10y  \
# 0         13.089416  35.610112      2.33      2.52      2.73       2.85
# 1         18.446072  41.815020      2.59      2.81      2.94       3.05
# 2         23.300936  80.638311      2.63      2.48      2.51       2.69
# 3         37.980535  13.417155      0.26      0.56      1.37       1.94
# 4         50.932689   8.717757      0.28      0.64      1.63       2.35
#
#    yield_30y  inflation_exp  inflation_urban_all  \
# 0       2.98            3.0              251.118
# 1       3.19            2.7              252.239
# 2       3.02            2.7              252.551
# 3       2.54            3.0              235.976
# 4       3.11            2.7              237.657
#
#    inflation_urban_ex_food_energy  fed_effective_rate  unemployment_rate  \
# 0                         257.449                1.91                4.0
# 1                         258.505                2.18                3.7
# 2                         259.934                2.40                3.9
# 3                         240.755                0.06                5.4
# 4                         242.064                0.08                5.3
#
#    crude_oil_price  inflation_Exp_1Y  inflation_Exp_2Y  inflation_Exp_5Y  \
# 0            67.87          1.590995          1.772140          1.924010
# 1            70.23          2.410015          2.206002          2.103109
# 2            49.52          1.981070          1.995989          2.019533
# 3            47.82          0.798439          1.190572          1.495196
# 4            59.82          1.775055          1.695114          1.711298
#
#    inflation_Exp_10Y  inflation_Exp_30Y  yield_spread   gdp_gap  is_inversion  \
# 0           2.045903           2.310123          0.33 -0.000528             0
# 1           2.136153           2.340414          0.24 -0.001140             0
# 2           2.091349           2.323323          0.21 -0.003243             0
# 3           1.703487           2.115891          1.38 -0.016728             0
# 4           1.824036           2.164157          1.71 -0.015586             0
#
#    log_market_cap  pe_ratio_gdp_gap  pe_ratio_yield_spread  \
# 0       22.891296         -0.018806              11.751337
# 1       22.742627         -0.047669              10.035605
# 2       22.324069         -0.261540              16.934045
# 3       24.327926         -0.224447              18.515673
# 4       24.043503         -0.135876              14.907365
#
#    pe_ratio_is_inversion  pb_ratio_gdp_gap  pb_ratio_yield_spread  \
# 0              11.751337         -0.000860               0.537360
# 1              10.035605         -0.001709               0.359881
# 2              16.934045         -0.003082               0.199573
# 3              18.515673         -0.304708              25.136831
# 4              14.907365         -0.156238              17.141407
#
#    pb_ratio_is_inversion  market_cap_gdp_gap  market_cap_yield_spread  \
# 0               0.537360       -4.616232e+06             2.884546e+09
# 1               0.359881       -8.588109e+06             1.808043e+09
# 2               0.199573       -1.607743e+07             1.040972e+09
# 3              25.136831       -6.150871e+08             5.074147e+10
# 4              17.141407       -4.312190e+08             4.731044e+10
#
#    market_cap_is_inversion  debt_to_ev_ratio_gdp_gap  \
# 0             2.884546e+09                 -0.006913
# 1             1.808043e+09                 -0.021028
# 2             1.040972e+09                 -0.075574
# 3             5.074147e+10                 -0.635351
# 4             4.731044e+10                 -0.793841
#
#    debt_to_ev_ratio_yield_spread  debt_to_ev_ratio_is_inversion     yq
# 0                       4.319507                       4.319507  20182
# 1                       4.427057                       4.427057  20183
# 2                       4.893196                       4.893196  20184
# 3                      52.413138                      52.413138  20151
# 4                      87.094898                      87.094898  20152

# %%
df_abt = df_abt.drop(['year', 'quarter'], axis = 1)

# %%
df_abt.to_csv('analytical_base_table.csv', index = None)

# %% [markdown]
# ## Algorithm Selection

# %%
from sklearn.model_selection import train_test_split
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, Ridge, ElasticNet
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.exceptions import NotFittedError
from sklearn.model_selection import GroupKFold

# %%
df_abt = pd.read_csv('analytical_base_table.csv')
df_abt.yq.unique()
# Out:
# array([20182, 20183, 20184, 20151, 20152, 20153, 20154, 20171, 20172,
#        20173, 20174, 20194, 20013, 20022, 20031, 20032, 20033, 20041,
#        20042, 20043, 20044, 20052, 20062, 20071, 20072, 20081, 20082,
#        20083, 20084, 20091, 20092, 20093, 20113, 20124, 20023, 20024,
#        20034, 20051, 20053, 20054, 20061, 20063, 20064, 20073, 20074,
#        20094, 20101, 20102, 20103, 20104, 20111, 20112, 20114, 20121,
#        20122, 20123, 20132, 20133, 20134, 20141, 20142, 20143, 20144,
#        20161, 20162, 20163, 20164, 20191, 20192, 20193, 20201, 20202,
#        20203, 20211, 20212, 20213, 20214, 20204, 20014, 20011, 20012],
#       dtype=int64)

# %%
y = df_abt["return_3m"]
X = df_abt.drop("return_3m", axis = 1)
X = X.drop('stock', axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2, random_state = 1234)

# %%
X_train.head()
# Out:
#         pb_ratio  long_term_growth  debt_to_ev_ratio    pe_ratio  yield_1y  \
# 14593   3.455185          14.53150         36.615824  113.035915      0.17
# 6237    4.734517          17.44000         18.875505   14.976009      0.25
# 7275    4.039139          11.72500         13.102532   23.711783      0.25
# 26772  12.389619         137.34000          4.435605   32.147573      0.09
# 16780   2.103321          12.33333          7.267821   12.907956      0.56
#
#        yield_2y  yield_5y  yield_10y  yield_30y  inflation_exp  \
# 14593      0.23      0.37       0.70       1.35            2.2
# 6237       0.67      1.65       2.17       2.75            2.8
# 7275       0.67      1.65       2.17       2.75            2.8
# 26772      0.28      0.98       1.52       2.08            4.6
# 16780      1.11      2.54       3.53       4.32            3.1
#
#        inflation_urban_all  inflation_urban_ex_food_energy  \
# 14593              258.165                         266.916
# 6237               236.252                         239.584
# 7275               236.252                         239.584
# 26772              274.214                         280.017
# 16780              214.790                         219.112
#
#        fed_effective_rate  unemployment_rate  crude_oil_price  \
# 14593                0.08                4.4            29.21
# 6237                 0.06                5.6            59.29
# 7275                 0.06                5.6            59.29
# 26772                0.06                4.7            71.65
# 16780                0.22                9.5            69.68
#
#        inflation_Exp_1Y  inflation_Exp_2Y  inflation_Exp_5Y  \
# 14593          0.987074          1.082918          1.121101
# 6237           2.186100          1.900503          1.783241
# 7275           2.186100          1.900503          1.783241
# 26772          2.684137          2.007175          1.632602
# 16780          1.274512          1.556176          1.819088
#
#        inflation_Exp_10Y  inflation_Exp_30Y  yield_spread   gdp_gap  \
# 14593           1.269775           1.814519          0.47 -0.016089
# 6237            1.852137           2.168506          1.50 -0.020656
# 7275            1.852137           2.168506          1.50 -0.020656
# 26772           1.642786           2.014232          1.24 -0.001325
# 16780           2.007327           2.375178          2.42 -0.053338
#
#        is_inversion  log_market_cap  pe_ratio_gdp_gap  pe_ratio_yield_spread  \
# 14593             0       23.758084         -1.818674              53.126880
# 6237              0       21.793645         -0.309351              22.464013
# 7275              0       22.942817         -0.489801              35.567674
# 26772             0       25.097053         -0.042598              39.862990
# 16780             0       19.825480         -0.688480              31.237253
#
#        pe_ratio_is_inversion  pb_ratio_gdp_gap  pb_ratio_yield_spread  \
# 14593              53.126880         -0.055592               1.623937
# 6237               22.464013         -0.097798               7.101776
# 7275               35.567674         -0.083434               6.058708
# 26772              39.862990         -0.016417              15.363127
# 16780              31.237253         -0.112186               5.090037
#
#        pb_ratio_is_inversion  market_cap_gdp_gap  market_cap_yield_spread  \
# 14593               1.623937       -3.346133e+08             9.774679e+09
# 6237                7.101776       -6.024417e+07             4.374727e+09
# 7275                6.058708       -1.901053e+08             1.380480e+10
# 26772              15.363127       -1.051374e+08             9.838598e+10
# 16780               5.090037       -2.173353e+07             9.860793e+08
#
#        market_cap_is_inversion  debt_to_ev_ratio_gdp_gap  \
# 14593             9.774679e+09                 -0.589125
# 6237              4.374727e+09                 -0.389901
# 7275              1.380480e+10                 -0.270652
# 26772             9.838598e+10                 -0.005878
# 16780             9.860793e+08                 -0.387648
#
#        debt_to_ev_ratio_yield_spread  debt_to_ev_ratio_is_inversion     yq
# 14593                      17.209437                      17.209437  20201
# 6237                       28.313258                      28.313258  20144
# 7275                       19.653797                      19.653797  20144
# 26772                       5.500150                       5.500150  20213
# 16780                      17.588126                      17.588126  20092

# %%
#group_labels = X_train['yq']
X_train = X_train.drop(columns = ['yq'], axis = 1)
X_test = X_test.drop(columns = ['yq'], axis = 1)

# %%
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 24506 6127 24506 6127

# %%
pipelines = {
    'lasso' : make_pipeline(StandardScaler(), Lasso(random_state=123)),
    'ridge' : make_pipeline(StandardScaler(), Ridge(random_state=123)),
    'enet': make_pipeline(StandardScaler(), ElasticNet(random_state=123)),
    'rf': make_pipeline(StandardScaler(), RandomForestRegressor(random_state=123)),
    'gb': make_pipeline(StandardScaler(), GradientBoostingRegressor(random_state=123))
}

# %%
lasso_hyperparameters = { 
    'lasso__alpha' : [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10] 
}
ridge_hyperparameters = { 
    'ridge__alpha': [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10]  
}
enet_hyperparameters = { 
    'elasticnet__alpha': [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10],                        
    'elasticnet__l1_ratio' : [0.1, 0.3, 0.5, 0.7, 0.9]  
}
rf_hyperparameters = { 
    'randomforestregressor__n_estimators' : [100, 200],
    'randomforestregressor__max_features': ['auto', 'sqrt', 0.33],
}
gb_hyperparameters = { 
    'gradientboostingregressor__n_estimators': [100, 200],
    'gradientboostingregressor__learning_rate' : [0.05, 0.1, 0.2],
    'gradientboostingregressor__max_depth': [1, 3, 5]
}

# %%
hyperparameters = {
    'rf' : rf_hyperparameters,
    'gb' : gb_hyperparameters,
    'lasso' : lasso_hyperparameters,
    'ridge' : ridge_hyperparameters,
    'enet' : enet_hyperparameters
}

# %% [markdown]
# ## Model Training

# %%
# Create empty dictionary called fitted_models
fitted_models = {}

# Loop through model pipelines, tuning each one and saving it to fitted_models
for name, pipeline in pipelines.items():
    model = GridSearchCV(pipeline, hyperparameters[name], cv=10, n_jobs=-1)
    
    # Fit model on X_train, y_train
    #model.fit(X_train, y_train, groups = group_labels )
    model.fit(X_train, y_train)
    
    # Store model in fitted_models[name] 
    fitted_models[name] = model
    
    # Print '{name} has been fitted'
    print(name, 'has been fitted.')
# Out:
# lasso has been fitted.
# ridge has been fitted.
# enet has been fitted.
# rf has been fitted.
# gb has been fitted.

# %%
for name, model in fitted_models.items():
    try:
        pred = model.predict(X_test)
        print(name, 'has been fitted.')
    except NotFittedError as e:
        print(repr(e))
# Out:
# lasso has been fitted.
# ridge has been fitted.
# enet has been fitted.
# rf has been fitted.
# gb has been fitted.

# %%
for name, model in fitted_models.items():
    print( name, model.best_score_ )
# Out:
# lasso 0.03504758643316027
# ridge -12.953736250943336
# enet 0.0331452049276888
# rf 0.3033973751505112
# gb 0.32688984265731713

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error

# %%
for name, model in fitted_models.items():
    pred = model.predict(X_test)
    print( name )
    print( '--------' )
    print( 'R^2:', r2_score(y_test, pred ))
    print( 'MAE:', mean_absolute_error(y_test, pred))
    print()
# Out:
# lasso
# --------
# R^2: 0.041637647100446595
# MAE: 11.699617485319209
#
# ridge
# --------
# R^2: 0.05733577449115068
# MAE: 11.699989933243945
#
# enet
# --------
# R^2: 0.04278459714191285
# MAE: 11.692125139270193
#
# rf
# --------
# R^2: 0.2853155160694295
# MAE: 10.158221689709704
#
# gb
# --------
# R^2: 0.2823429087818051
# MAE: 10.161094326880788

# %%
import pickle
with open('final_model.pkl', 'wb') as f: pickle.dump(fitted_models['rf'].best_estimator_, f)

# %% [markdown]
# ## Identify Stocks with Abnormal Returns

# %%
# Identify stocks that underperformed a lot in 2022Q1.
with open('final_model.pkl', 'rb') as f: rfmodel = pickle.load(f)
df_abt = pd.read_csv('analytical_base_table.csv')
df_2022Q1 = df_abt[df_abt.yq == 20214]
y = df_abt[["return_3m", 'stock']]
X = df_abt.drop("return_3m", axis = 1)
X = X.drop(['yq', 'stock'], axis = 1)

# %%
y['predicted_return'] = rfmodel.predict(X)
# Out:
# C:\Users\rohhe\AppData\Local\Temp/ipykernel_23936/1433858054.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['predicted_return'] = rfmodel.predict(X)

# %%
y['deviation'] = y['return_3m'] - y['predicted_return']
# Out:
# C:\Users\rohhe\AppData\Local\Temp/ipykernel_23936/1879938959.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['deviation'] = y['return_3m'] - y['predicted_return']

# %%
y = y.sort_values('deviation')

# %%
y[0:20]
# Out:
#        return_3m   stock  predicted_return  deviation
# 30507 -34.469997    ZD.O         45.669724 -80.139722
# 24977 -58.705673  SLCA.K          5.863184 -64.568857
# 23505  -2.503129  RMBS.O         56.552893 -59.056022
# 10974  -7.692308  FLWS.O         49.520334 -57.212642
# 14615 -34.667451  IRMD.O         22.095624 -56.763075
# 17030 -41.480298  LQDT.O         12.850617 -54.330915
# 2645  -47.803347  AXON.O          4.982160 -52.785507
# 24165 -72.605482  SABR.O        -19.963979 -52.641503
# 20558 -42.322384     OCN          9.685638 -52.008021
# 26209 -61.656442    TA.O        -10.118016 -51.538426
# 9769  -43.411928  EVRI.K          6.503962 -49.915890
# 15043 -30.299090  JBLU.O         19.534261 -49.833350
# 23050 -38.811513  QDEL.O         10.886755 -49.698268
# 2039  -36.894004  ARCB.O         11.338817 -48.232821
# 7697  -75.855131   CZR.O        -27.937318 -47.917813
# 23047 -22.393736  QDEL.O         25.452760 -47.846496
# 12572 -25.870179  GTLS.K         21.752892 -47.623070
# 26302 -41.761364     TCS          5.529918 -47.291281
# 27412  -5.348109  TSLA.O         41.451634 -46.799743
# 13090 -32.043902      HL         13.791940 -45.835842

# %%
y.to_csv('predicted_return_2022Q1.csv')
